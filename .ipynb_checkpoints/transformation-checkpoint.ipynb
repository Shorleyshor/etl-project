# %%
# Importing Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Setting csv path and loading the first csv into Pandas DataFrame

tb_rates_csv = "Resources/tb_rates.csv"
tb_rates_df = pd.read_csv(tb_rates_csv)
tb_rates_df.head()
# Out:
#           Country National data Report type  2012 Cases 2012 Rate   ASR  \
# 0         Austria             Y           C         648       7.7   7.6
# 1         Belgium             Y           C         987       8.9   9.1
# 2        Bulgaria             Y           C        2280      31.1  30.6
# 3          Cyprus             Y           C          69         8   7.8
# 4  Czech Republic             Y           C         605       5.8   5.6
#
#   Confirmed cases  2011 Cases 2011 Rate  2010 Cases 2010 Rate 2009 Cases  \
# 0             413         690       8.2         691       8.3        696
# 1             776        1019       9.3        1086        10        994
# 2            1092        2406      32.6        2649        35       2910
# 3              50          54       6.4          61       7.4         55
# 4             421         600       5.7         668       6.4        694
#
#   2009 Rate 2008 Cases 2008 Rate
# 0       8.3        817       9.8
# ...

# %%
# Dropping unwanted columns

new_df = tb_rates_df.drop(["National data", "Report type", "ASR", "Confirmed cases"], axis=1)
new_df.head()
# Out:
#           Country  2012 Cases 2012 Rate  2011 Cases 2011 Rate  2010 Cases  \
# 0         Austria         648       7.7         690       8.2         691
# 1         Belgium         987       8.9        1019       9.3        1086
# 2        Bulgaria        2280      31.1        2406      32.6        2649
# 3          Cyprus          69         8          54       6.4          61
# 4  Czech Republic         605       5.8         600       5.7         668
#
#   2010 Rate 2009 Cases 2009 Rate 2008 Cases 2008 Rate
# 0       8.3        696       8.3        817       9.8
# 1        10        994       9.2        990       9.3
# 2        35       2910      38.3       3150      41.2
# 3       7.4         55       6.9         50       6.3
# 4       6.4        694       6.7        864       8.3

# %%
# Dropping Unwanted role by index

new_tb_rates_df = tb_rates_df.drop([27, 29], axis=0)
new_tb_rates_df.head()
# Out:
#           Country National data Report type  2012 Cases 2012 Rate   ASR  \
# 0         Austria             Y           C         648       7.7   7.6
# 1         Belgium             Y           C         987       8.9   9.1
# 2        Bulgaria             Y           C        2280      31.1  30.6
# 3          Cyprus             Y           C          69         8   7.8
# 4  Czech Republic             Y           C         605       5.8   5.6
#
#   Confirmed cases  2011 Cases 2011 Rate  2010 Cases 2010 Rate 2009 Cases  \
# 0             413         690       8.2         691       8.3        696
# 1             776        1019       9.3        1086        10        994
# 2            1092        2406      32.6        2649        35       2910
# 3              50          54       6.4          61       7.4         55
# 4             421         600       5.7         668       6.4        694
#
#   2009 Rate 2008 Cases 2008 Rate
# 0       8.3        817       9.8
# ...

# %%
eu_countries = new_tb_rates_df["Country"]
eu_list = eu_countries.to_list()
eu_list
# Out:
# ['Austria',
#  'Belgium',
#  'Bulgaria',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Netherlands',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'United Kingdom',
#  'Iceland',
#  'Norway']

# %%
immunisation_csv = "./datasets/BSG_NEW.csv"
immunisation_df = pd.read_csv(immunisation_csv)
immunisation_df
# Out:
#                                 Country  2012  2011  2010  2009  2008
# 0                           Afghanistan  78.0  71.0  68.0  64.0  66.0
# 1                               Albania  96.0  97.0  99.0  97.0  99.0
# 2                               Algeria  99.0  99.0  99.0  99.0  99.0
# 3                                Angola  73.0  74.0  79.0  70.0  73.0
# 4                             Argentina  99.0  99.0  99.0  99.0  99.0
# ..                                  ...   ...   ...   ...   ...   ...
# 159  Venezuela (Bolivarian Republic of)  96.0  95.0  92.0  91.0  90.0
# 160                            Viet Nam  98.0  98.0  94.0  97.0  92.0
# 161                               Yemen  64.0  59.0  65.0  58.0  60.0
# 162                              Zambia  92.0  92.0  92.0  92.0  91.0
# 163                            Zimbabwe  98.0  98.0  99.0  90.0  91.0
#
# [164 rows x 6 columns]

# %%
eu_df = immunisation_df.loc[immunisation_df["Country"] == new_tb_rates_df["Country"]]
eu_df
#==new_tb_rates_df.loc["Country"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13396\2474862961.py in <module>
# ----> 1 eu_df = immunisation_df.loc[immunisation_df["Country"] == new_tb_rates_df["Country"]]
#       2 eu_df
#       3 #==new_tb_rates_df.loc["Country"]]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     522
#     523         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 524             raise ValueError("Can only compare identically-labeled Series objects")
#     525
#     526         lvalues = extract_array(self, extract_numpy=True)
#
# ...

# %%
boolean_df = immunisation_df.isin([eu_list])
boolean_df.head(53)
# Out:
#     Country   2012   2011   2010   2009   2008
# 0     False  False  False  False  False  False
# 1     False  False  False  False  False  False
# 2     False  False  False  False  False  False
# 3     False  False  False  False  False  False
# 4     False  False  False  False  False  False
# 5     False  False  False  False  False  False
# 6     False  False  False  False  False  False
# 7     False  False  False  False  False  False
# 8     False  False  False  False  False  False
# 9     False  False  False  False  False  False
# 10    False  False  False  False  False  False
# 11    False  False  False  False  False  False
# 12    False  False  False  False  False  False
# 13    False  False  False  False  False  False
# 14    False  False  False  False  False  False
# 15    False  False  False  False  False  False
# 16    False  False  False  False  False  False
# 17    False  False  False  False  False  False
# 18    False  False  False  False  False  False
# ...

# %%
protocol = 'postgresql'
username = '<postgresql>'
password = '<password>'
host = 'localhost'
port = 5432
database_name = 'tuberculosis_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2344         try:
# -> 2345             return fn()
#    2346         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
# ...
