# %%
# Importing Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Creating csv path and loading first data in Pandas DataFrame
tb_rates_csv = "Resources/tb_rates.csv"
tb_rates_df = pd.read_csv(tb_rates_csv)
tb_rates_df.head()
# Out:
#           Country National data Report type  2012 Cases 2012 Rate   ASR  \
# 0         Austria             Y           C         648       7.7   7.6
# 1         Belgium             Y           C         987       8.9   9.1
# 2        Bulgaria             Y           C        2280      31.1  30.6
# 3          Cyprus             Y           C          69         8   7.8
# 4  Czech Republic             Y           C         605       5.8   5.6
#
#   Confirmed cases  2011 Cases 2011 Rate  2010 Cases 2010 Rate 2009 Cases  \
# 0             413         690       8.2         691       8.3        696
# 1             776        1019       9.3        1086        10        994
# 2            1092        2406      32.6        2649        35       2910
# 3              50          54       6.4          61       7.4         55
# 4             421         600       5.7         668       6.4        694
#
#   2009 Rate 2008 Cases 2008 Rate
# 0       8.3        817       9.8
# ...

# %%
# Dropping/removing unwanted columns
tb_rates_df.drop(["National data", "Report type", "ASR", "Confirmed cases"], axis=1, inplace=True)

# %%
# Dropping/removing unwanted rows
new_tb_rates_df = tb_rates_df.drop([27, 29], axis=0)
new_tb_rates_df.head()
# Out:
#           Country  2012 Cases 2012 Rate  2011 Cases 2011 Rate  2010 Cases  \
# 0         Austria         648       7.7         690       8.2         691
# 1         Belgium         987       8.9        1019       9.3        1086
# 2        Bulgaria        2280      31.1        2406      32.6        2649
# 3          Cyprus          69         8          54       6.4          61
# 4  Czech Republic         605       5.8         600       5.7         668
#
#   2010 Rate 2009 Cases 2009 Rate 2008 Cases 2008 Rate
# 0       8.3        696       8.3        817       9.8
# 1        10        994       9.2        990       9.3
# 2        35       2910      38.3       3150      41.2
# 3       7.4         55       6.9         50       6.3
# 4       6.4        694       6.7        864       8.3

# %%
data={"Country":"id","2012 Cases":"2012_cases","2012 Rate":"2012_rate","2011 Cases":"2011_cases","2011 Rate":"2011_rate","2010 Cases":"2010_cases", "2010 Rate":"2010_rate","2009 Cases":"2009_cases","2009 Rate":"2009_rate","2008 Cases":"2008_cases","2008 Rate":"2008_rate"}
                                      
new_tb_rates_df.rename(columns=data, inplace = True)

# %%
new_tb_rates_df.head()
# Out:
#                id  2012 Cases 2012_rate  2011 Cases 2011_rate  2010 Cases  \
# 0         Austria         648       7.7         690       8.2         691
# 1         Belgium         987       8.9        1019       9.3        1086
# 2        Bulgaria        2280      31.1        2406      32.6        2649
# 3          Cyprus          69         8          54       6.4          61
# 4  Czech Republic         605       5.8         600       5.7         668
#
#   2010_rate 2009_cases 2009_rate 2008_cases 2008_rate
# 0       8.3        696       8.3        817       9.8
# 1        10        994       9.2        990       9.3
# 2        35       2910      38.3       3150      41.2
# 3       7.4         55       6.9         50       6.3
# 4       6.4        694       6.7        864       8.3

# %%
# Clean the data by dropping duplicates and setting the index
new_tb_rates_df.drop_duplicates("id", inplace=True)
new_tb_rates_df.set_index("id", inplace=True)

new_tb_rates_df.head()
# Out:
#                 2012 Cases 2012_rate  2011 Cases 2011_rate  2010 Cases  \
# id
# Austria                648       7.7         690       8.2         691
# Belgium                987       8.9        1019       9.3        1086
# Bulgaria              2280      31.1        2406      32.6        2649
# Cyprus                  69         8          54       6.4          61
# Czech Republic         605       5.8         600       5.7         668
#
#                2010_rate 2009_cases 2009_rate 2008_cases 2008_rate
# id
# Austria              8.3        696       8.3        817       9.8
# Belgium               10        994       9.2        990       9.3
# Bulgaria              35       2910      38.3       3150      41.2
# Cyprus               7.4         55       6.9         50       6.3
# Czech Republic       6.4        694       6.7        864       8.3

# %%
# Creating csv path and loading second data set in Pandas DataFrame
csv_path = "Resources/BCG_vaccine.csv"
vaccine_df = pd.read_csv(csv_path)
vaccine_df.head()
# Out:
#          Country / Region Antigen Data source  2012  2011  2010  2009  2008
# 0                 Albania     BCG      WUENIC  0.96  0.97  0.99  0.97  0.99
# 1                 Armenia     BCG      WUENIC  0.96  0.96  0.95  0.99  0.98
# 2              Azerbaijan     BCG      WUENIC  0.98  0.99  0.98  0.95  0.92
# 3                 Belarus     BCG      WUENIC  0.98  0.99  0.99  0.98  0.98
# 4  Bosnia and Herzegovina     BCG      WUENIC  0.96  0.94  0.96  0.97  0.96

# %%
vaccine_cols = ['Country / Region', '2012', '2011', '2010', '2009', '2008']
vaccine_transformed= vaccine_df[vaccine_cols].copy()


# Rename the column headers
vaccine_transformed = vaccine_transformed.rename(columns={"Country / Region": "id"})

# Clean the data by dropping duplicates and setting the index
vaccine_transformed.drop_duplicates("id", inplace=True)
vaccine_transformed.set_index("id", inplace=True)

vaccine_transformed.head()
# Out:
#                         2012  2011  2010  2009  2008
# id
# Albania                 0.96  0.97  0.99  0.97  0.99
# Armenia                 0.96  0.96  0.95  0.99  0.98
# Azerbaijan              0.98  0.99  0.98  0.95  0.92
# Belarus                 0.98  0.99  0.99  0.98  0.98
# Bosnia and Herzegovina  0.96  0.94  0.96  0.97  0.96

# %%
vaccine_transformed.dropna()
# Out:
#                         2012  2011  2010  2009  2008
# id
# Albania                 0.96  0.97  0.99  0.97  0.99
# Armenia                 0.96  0.96  0.95  0.99  0.98
# Azerbaijan              0.98  0.99  0.98  0.95  0.92
# Belarus                 0.98  0.99  0.99  0.98  0.98
# Bosnia and Herzegovina  0.96  0.94  0.96  0.97  0.96
# Bulgaria                0.97  0.98  0.98  0.98  0.98
# Croatia                 0.99  0.99  0.99  0.99  0.99
# Estonia                 0.97  0.99  0.97  0.97  0.98
# Georgia                 0.95  0.96  0.96  0.95  0.95
# Hungary                 0.99  0.99  0.99  0.99  0.99
# Ireland                 0.42  0.41  0.30  0.30  0.34
# Kazakhstan              0.95  0.96  0.96  0.96  0.97
# Kyrgyzstan              0.98  0.98  0.98  0.98  0.99
# Latvia                  0.94  0.93  0.92  0.96  0.95
# Lithuania               0.98  0.98  0.99  0.99  0.99
# Monaco                  0.89  0.89  0.89  0.89  0.89
# Montenegro              0.95  0.97  0.95  0.95  0.98
# ...

# %%
protocol = 'postgresql'
username = '<postgres>'
password = '<akinbola1984>'
host = 'localhost'
port = 5432
database_name = 'tuberculosis_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
#engine = create_engine(rds_connection_string)
engine = create_engine('postgresql+psycopg2://postgres:akinbola1984@localhost/tuberculosis_db')

# %%
engine.table_names()
# Out:
# /Users/ola/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# ['reported_cases', 'vaccine_coverage']

# %% [markdown]
# # Use pandas to load csv converted DataFrame into database

# %%
#new_tb_rates_df.to_sql(name='reported_cases', con=engine, if_exists='append', index=False)

# %%
vaccine_transformed.to_sql(name='vaccine_coverage', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1799                     self.dialect.do_executemany(
# -> 1800                         cursor, statement, parameters, context
#    1801                     )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     958                 fetch=bool(context.compiled.returning),
# --> 959                 **kwargs
#     960             )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# ...

# %%
vaccine_df.to_sql(name='#vaccine_coverage', con=engine, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None, method=None)
